# %% [markdown]
# # DOWNLOAD DATA FROM COPERNICUS MARINE

# %%
# !pip install cartopy
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.24.1-cp313-cp313-win_amd64.whl.metadata (8.1 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ratna\anaconda3\lib\site-packages (from cartopy) (2.1.3)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\ratna\anaconda3\lib\site-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=1.8 in c:\users\ratna\anaconda3\lib\site-packages (from cartopy) (2.1.1)
# Requirement already satisfied: packaging>=21 in c:\users\ratna\anaconda3\lib\site-packages (from cartopy) (24.2)
# Collecting pyshp>=2.3 (from cartopy)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\ratna\anaconda3\lib\site-packages (from cartopy) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\ratna\anaconda3\lib\site-packages (from pyproj>=3.3.1->cartopy) (2025.6.15)
# Requirement already satisfied: six>=1.5 in c:\users\ratna\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Downloading Cartopy-0.24.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------ --------------------------- 3.4/11.0 MB 17.6 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 19.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 17.5 MB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Installing collected packages: pyshp, cartopy
#
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    ---------------------------------------- 2/2 [cartopy]
#
# Successfully installed cartopy-0.24.1 pyshp-2.3.1

# %%
import sys 
# !{sys.executable} -m pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# aext-assistant                    4.20.0
# aext-assistant-server             4.20.0
# aext-core                         4.20.0
# aext-core-server                  4.20.0
# aext_environments_server          4.20.0
# aext-panels                       4.20.0
# aext-panels-server                4.20.0
# aext-project-filebrowser-server   4.20.0
# aext-share-notebook               4.20.0
# aext-share-notebook-server        4.20.0
# aext-shared                       4.20.0
# aext-toolbox                      4.20.0
# aiobotocore                       2.19.0
# aiohappyeyeballs                  2.4.4
# aiohttp                           3.11.10
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# alembic                           1.15.2
# altair                            5.5.0
# anaconda-anon-usage               0.7.1
# anaconda-auth                     0.8.6
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.5.2
# anaconda-client                   1.13.0
# anaconda-navigator                2.6.6
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.7.0
# appdirs                           1.4.4
# archspec                          0.2.3
# arcosparse                        0.4.2
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# astroid                           3.3.8
# astropy                           7.0.0
# astropy-iers-data                 0.2025.1.13.0.34.51
# asttokens                         3.0.0
# async-lru                         2.0.4
# asyncssh                          2.17.0
# atomicwrites                      1.4.0
# attrs                             24.3.0
# Automat                           24.8.1
# autopep8                          2.0.4
# babel                             2.16.0
# bcrypt                            4.3.0
# beautifulsoup4                    4.12.3
# binaryornot                       0.4.4
# black                             24.10.0
# bleach                            6.2.0
# blinker                           1.9.0
# bokeh                             3.6.2
# boltons                           24.1.0
# boto3                             1.38.45
# botocore                          1.38.45
# Bottleneck                        1.4.2
# Brotli                            1.0.9
# cachetools                        5.5.1
# certifi                           2025.6.15
# cffi                              1.17.1
# chardet                           4.0.0
# charset-normalizer                3.3.2
# click                             8.1.8
# cloudpickle                       3.0.0
# cmocean                           4.0.3
# colorama                          0.4.6
# colorcet                          3.1.0
# comm                              0.2.1
# conda                             25.5.1
# conda-anaconda-telemetry          0.1.2
# conda-anaconda-tos                0.2.0
# conda-build                       25.5.0
# conda-content-trust               0.2.0
# conda_index                       0.6.1
# conda-libmamba-solver             25.4.0
# conda-pack                        0.7.1
# conda-package-handling            2.4.0
# conda_package_streaming           0.11.0
# conda-repo-cli                    1.0.165
# conda-token                       0.6.0
# constantly                        23.10.4
# contourpy                         1.3.1
# cookiecutter                      1.7.3
# copernicusmarine                  2.1.2
# crc32c                            2.7.1
# cryptography                      44.0.1
# cssselect                         1.2.0
# cycler                            0.11.0
# cytoolz                           1.0.1
# dask                              2025.2.0
# dask-expr                         2.0.0
# datashader                        0.18.0
# debugpy                           1.8.11
# decorator                         5.1.1
# defusedxml                        0.7.1
# Deprecated                        1.2.13
# diff-match-patch                  20200713
# dill                              0.3.8
# distributed                       2025.2.0
# distro                            1.9.0
# docstring-to-markdown             0.11
# docutils                          0.21.2
# donfig                            0.8.1.post1
# et_xmlfile                        1.1.0
# evalidate                         2.0.3
# executing                         0.8.3
# fastjsonschema                    2.20.0
# filelock                          3.17.0
# flake8                            7.1.1
# Flask                             3.1.0
# fonttools                         4.55.3
# frozendict                        2.4.2
# frozenlist                        1.5.0
# fsspec                            2025.3.2
# gitdb                             4.0.7
# GitPython                         3.1.43
# gmpy2                             2.2.1
# greenlet                          3.1.1
# h11                               0.16.0
# h5netcdf                          1.6.2
# h5py                              3.12.1
# HeapDict                          1.0.1
# holoviews                         1.20.2
# httpcore                          1.0.9
# httpx                             0.28.1
# hvplot                            0.11.3
# hyperlink                         21.0.0
# idna                              3.7
# imageio                           2.37.0
# imagesize                         1.4.1
# imbalanced-learn                  0.13.0
# importlib_metadata                8.5.0
# incremental                       24.7.2
# inflection                        0.5.1
# iniconfig                         1.1.1
# intake                            2.0.7
# intervaltree                      3.1.0
# ipykernel                         6.29.5
# ipython                           8.30.0
# ipywidgets                        8.1.5
# isort                             6.0.1
# itemadapter                       0.3.0
# itemloaders                       1.3.2
# itsdangerous                      2.2.0
# jaraco.classes                    3.2.1
# jaraco.context                    0.0.0
# jaraco.functools                  4.1.0
# jedi                              0.19.2
# jellyfish                         1.1.3
# Jinja2                            3.1.6
# jinja2-time                       0.2.0
# jmespath                          1.0.1
# joblib                            1.4.2
# json5                             0.9.25
# jsonpatch                         1.33
# jsonpointer                       2.1
# jsonschema                        4.23.0
# jsonschema-specifications         2023.7.1
# jupyter                           1.1.1
# jupyter_client                    8.6.3
# jupyter-console                   6.6.3
# jupyter_core                      5.7.2
# jupyter-events                    0.12.0
# jupyter-lsp                       2.2.5
# jupyter_server                    2.15.0
# jupyter_server_terminals          0.5.3
# jupyterlab                        4.3.4
# jupyterlab_pygments               0.3.0
# jupyterlab_server                 2.27.3
# jupyterlab_widgets                3.0.13
# keyring                           25.6.0
# kiwisolver                        1.4.8
# lazy_loader                       0.4
# lckr_jupyterlab_variableinspector 3.2.4
# libarchive-c                      5.1
# libmambapy                        2.0.5
# lief                              0.16.4
# linkify-it-py                     2.0.0
# llvmlite                          0.44.0
# lmdb                              1.6.2
# locket                            1.0.0
# lxml                              5.3.0
# lz4                               4.3.2
# Mako                              1.2.3
# Markdown                          3.8
# markdown-it-py                    2.2.0
# MarkupSafe                        3.0.2
# matplotlib                        3.10.0
# matplotlib-inline                 0.1.6
# mccabe                            0.7.0
# mdit-py-plugins                   0.3.0
# mdurl                             0.1.0
# menuinst                          2.2.0
# mistune                           3.1.2
# mkl_fft                           1.3.11
# mkl_random                        1.2.8
# mkl-service                       2.4.0
# more-itertools                    10.3.0
# mpmath                            1.3.0
# msgpack                           1.0.3
# multidict                         6.1.0
# multipledispatch                  0.6.0
# mypy                              1.14.1
# mypy_extensions                   1.0.0
# narwhals                          1.31.0
# navigator-updater                 0.5.1
# nb_conda_kernels                  2.5.2
# nbclient                          0.10.2
# nbconvert                         7.16.6
# nbformat                          5.10.4
# nest_asyncio                      1.6.0
# networkx                          3.4.2
# nltk                              3.9.1
# notebook                          7.3.2
# notebook_shim                     0.2.4
# numba                             0.61.0
# numcodecs                         0.16.1
# numexpr                           2.10.1
# numpy                             2.1.3
# numpydoc                          1.7.0
# openpyxl                          3.1.5
# overrides                         7.4.0
# packaging                         24.2
# pandas                            2.2.3
# pandocfilters                     1.5.0
# panel                             1.7.0
# param                             2.2.0
# parsel                            1.8.1
# parso                             0.8.4
# partd                             1.4.2
# pathspec                          0.10.3
# patsy                             1.0.1
# pexpect                           4.8.0
# pickleshare                       0.7.5
# pillow                            11.1.0
# pip                               25.1
# pkce                              1.0.3
# pkginfo                           1.12.0
# platformdirs                      4.3.7
# plotly                            5.24.1
# pluggy                            1.5.0
# ply                               3.11
# poyo                              0.5.0
# prometheus_client                 0.21.1
# prompt_toolkit                    3.0.43
# propcache                         0.3.1
# Protego                           0.4.0
# protobuf                          5.29.3
# psutil                            5.9.0
# ptyprocess                        0.7.0
# pure-eval                         0.2.2
# py-cpuinfo                        9.0.0
# pyarrow                           19.0.0
# pyasn1                            0.4.8
# pyasn1-modules                    0.2.8
# pycodestyle                       2.12.1
# pycosat                           0.6.6
# pycparser                         2.21
# pyct                              0.5.0
# pycurl                            7.45.6
# pydantic                          2.10.3
# pydantic_core                     2.27.1
# pydantic-settings                 2.6.1
# PyDispatcher                      2.0.5
# pydocstyle                        6.3.0
# pyerfa                            2.0.1.5
# pyflakes                          3.2.0
# PyGithub                          2.4.0
# Pygments                          2.19.1
# PyJWT                             2.10.1
# pylint                            3.3.5
# pylint-venv                       3.0.3
# pyls-spyder                       0.4.0
# PyNaCl                            1.5.0
# pyodbc                            5.2.0
# pyOpenSSL                         25.0.0
# pyparsing                         3.2.0
# PyQt5                             5.15.10
# PyQt5_sip                         12.13.0
# PyQtWebEngine                     5.15.6
# PySocks                           1.7.1
# pystac                            1.13.0
# pytest                            8.3.4
# python-dateutil                   2.9.0.post0
# python-dotenv                     1.1.0
# python-json-logger                3.2.1
# python-lsp-black                  2.0.0
# python-lsp-jsonrpc                1.1.2
# python-lsp-server                 1.12.2
# python-slugify                    5.0.2
# pytoolconfig                      1.2.6
# pytz                              2024.1
# pyuca                             1.2
# pyviz_comms                       3.0.2
# PyWavelets                        1.8.0
# pywin32                           308
# pywin32-ctypes                    0.2.2
# pywinpty                          2.0.15
# PyYAML                            6.0.2
# pyzmq                             26.2.0
# QDarkStyle                        3.2.3
# qstylizer                         0.2.2
# QtAwesome                         1.4.0
# qtconsole                         5.6.1
# QtPy                              2.4.1
# queuelib                          1.6.2
# readchar                          4.0.5
# referencing                       0.30.2
# regex                             2024.11.6
# requests                          2.32.3
# requests-file                     2.1.0
# requests-toolbelt                 1.0.0
# rfc3339_validator                 0.1.4
# rfc3986_validator                 0.1.1
# rich                              13.9.4
# roman-numerals-py                 3.1.0
# rope                              1.13.0
# rpds-py                           0.22.3
# Rtree                             1.0.1
# ruamel.yaml                       0.18.10
# ruamel.yaml.clib                  0.2.12
# ruamel_yaml_conda                 0.17.21
# s3fs                              2025.3.2
# s3transfer                        0.13.0
# scikit-image                      0.25.0
# scikit-learn                      1.6.1
# scipy                             1.15.3
# Scrapy                            2.12.0
# seaborn                           0.13.2
# semver                            3.0.2
# Send2Trash                        1.8.2
# sentry-sdk                        2.18.0
# service-identity                  24.2.0
# setuptools                        72.1.0
# shellingham                       1.5.0
# sip                               6.7.12
# six                               1.17.0
# sklearn-compat                    0.1.3
# smmap                             4.0.0
# sniffio                           1.3.0
# snowballstemmer                   2.2.0
# sortedcontainers                  2.4.0
# soupsieve                         2.5
# Sphinx                            8.2.3
# sphinxcontrib-applehelp           2.0.0
# sphinxcontrib-devhelp             2.0.0
# sphinxcontrib-htmlhelp            2.1.0
# sphinxcontrib-jsmath              1.0.1
# sphinxcontrib-qthelp              2.0.0
# sphinxcontrib-serializinghtml     2.0.0
# spyder                            6.0.7
# spyder-kernels                    3.0.5
# SQLAlchemy                        2.0.39
# stack-data                        0.2.0
# statsmodels                       0.14.4
# streamlit                         1.45.1
# superqt                           0.7.3
# sympy                             1.13.3
# tables                            3.10.2
# tabulate                          0.9.0
# tblib                             3.1.0
# tenacity                          9.0.0
# terminado                         0.17.1
# text-unidecode                    1.3
# textdistance                      4.6.3
# threadpoolctl                     3.5.0
# three-merge                       0.1.1
# tifffile                          2025.2.18
# tinycss2                          1.4.0
# tldextract                        5.1.2
# toml                              0.10.2
# tomli                             2.0.1
# tomlkit                           0.13.2
# toolz                             1.0.0
# tornado                           6.5.1
# tqdm                              4.67.1
# traitlets                         5.14.3
# truststore                        0.10.0
# Twisted                           24.11.0
# twisted-iocpsupport               1.0.2
# typer                             0.9.0
# typing_extensions                 4.12.2
# tzdata                            2025.2
# uc-micro-py                       1.0.1
# ujson                             5.10.0
# Unidecode                         1.3.8
# urllib3                           2.3.0
# w3lib                             2.1.2
# watchdog                          4.0.2
# wcwidth                           0.2.5
# webencodings                      0.5.1
# websocket-client                  1.8.0
# Werkzeug                          3.1.3
# whatthepatch                      1.0.2
# wheel                             0.45.1
# widgetsnbextension                4.0.13
# win_inet_pton                     1.1.0
# wrapt                             1.17.0
# xarray                            2025.4.0
# xlwings                           0.32.1
# xyzservices                       2022.9.0
# yapf                              0.40.2
# yarl                              1.18.0
# zarr                              3.0.8
# zict                              3.0.0
# zipp                              3.21.0
# zope.interface                    7.1.1
# zstandard                         0.23.0

# %% [markdown]
# **Install copernicusmarine toolbox to download data**

# %%
# !pip install cmocean
# Out:
# Collecting cmocean
#   Downloading cmocean-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: matplotlib in c:\users\ratna\anaconda3\lib\site-packages (from cmocean) (3.10.0)
# Requirement already satisfied: numpy in c:\users\ratna\anaconda3\lib\site-packages (from cmocean) (2.1.3)
# Requirement already satisfied: packaging in c:\users\ratna\anaconda3\lib\site-packages (from cmocean) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ratna\anaconda3\lib\site-packages (from matplotlib->cmocean) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ratna\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->cmocean) (1.17.0)
# Downloading cmocean-4.0.3-py3-none-any.whl (421 kB)
# Installing collected packages: cmocean
# Successfully installed cmocean-4.0.3

# %%
# !pip install copernicusmarine
import copernicusmarine
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.19.0 requires botocore<1.36.4,>=1.36.0, but you have botocore 1.38.45 which is incompatible.
# Collecting copernicusmarine
#   Downloading copernicusmarine-2.1.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting arcosparse<0.5.0,>=0.4.0 (from copernicusmarine)
#   Downloading arcosparse-0.4.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting boto3>=1.26 (from copernicusmarine)
#   Downloading boto3-1.38.45-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: click!=8.2.0,>=8.0.4 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (8.1.8)
# Requirement already satisfied: dask>=2022 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (2025.2.0)
# Collecting h5netcdf<2.0.0,>=1.4.0 (from copernicusmarine)
#   Downloading h5netcdf-1.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: lxml>=4.9.0 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (5.3.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (2.1.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.1 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (2.10.3)
# Collecting pystac>=1.8.3 (from copernicusmarine)
#   Downloading pystac-1.13.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: requests>=2.27.1 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (2.32.3)
# Requirement already satisfied: semver>=3.0.2 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (3.0.2)
# Requirement already satisfied: setuptools>=68.2.2 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (72.1.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (4.67.1)
# Requirement already satisfied: xarray>=2023.4.0 in c:\users\ratna\anaconda3\lib\site-packages (from copernicusmarine) (2025.4.0)
# Collecting zarr>=2.13.3 (from copernicusmarine)
#   Downloading zarr-3.0.8-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: pandas<3,>=2 in c:\users\ratna\anaconda3\lib\site-packages (from arcosparse<0.5.0,>=0.4.0->copernicusmarine) (2.2.3)
# Requirement already satisfied: pyarrow>=17.0.0 in c:\users\ratna\anaconda3\lib\site-packages (from arcosparse<0.5.0,>=0.4.0->copernicusmarine) (19.0.0)
# Requirement already satisfied: h5py in c:\users\ratna\anaconda3\lib\site-packages (from h5netcdf<2.0.0,>=1.4.0->copernicusmarine) (3.12.1)
# Requirement already satisfied: packaging in c:\users\ratna\anaconda3\lib\site-packages (from h5netcdf<2.0.0,>=1.4.0->copernicusmarine) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ratna\anaconda3\lib\site-packages (from pandas<3,>=2->arcosparse<0.5.0,>=0.4.0->copernicusmarine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ratna\anaconda3\lib\site-packages (from pandas<3,>=2->arcosparse<0.5.0,>=0.4.0->copernicusmarine) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ratna\anaconda3\lib\site-packages (from pandas<3,>=2->arcosparse<0.5.0,>=0.4.0->copernicusmarine) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ratna\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\ratna\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\ratna\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.1->copernicusmarine) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ratna\anaconda3\lib\site-packages (from requests>=2.27.1->copernicusmarine) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ratna\anaconda3\lib\site-packages (from requests>=2.27.1->copernicusmarine) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ratna\anaconda3\lib\site-packages (from requests>=2.27.1->copernicusmarine) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ratna\anaconda3\lib\site-packages (from requests>=2.27.1->copernicusmarine) (2025.6.15)
# Requirement already satisfied: colorama in c:\users\ratna\anaconda3\lib\site-packages (from tqdm>=4.65.0->copernicusmarine) (0.4.6)
# Collecting botocore<1.39.0,>=1.38.45 (from boto3>=1.26->copernicusmarine)
#   Downloading botocore-1.38.45-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ratna\anaconda3\lib\site-packages (from boto3>=1.26->copernicusmarine) (1.0.1)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3>=1.26->copernicusmarine)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ratna\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=2->arcosparse<0.5.0,>=0.4.0->copernicusmarine) (1.17.0)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\ratna\anaconda3\lib\site-packages (from dask>=2022->copernicusmarine) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\ratna\anaconda3\lib\site-packages (from dask>=2022->copernicusmarine) (2025.3.2)
# Requirement already satisfied: partd>=1.4.0 in c:\users\ratna\anaconda3\lib\site-packages (from dask>=2022->copernicusmarine) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ratna\anaconda3\lib\site-packages (from dask>=2022->copernicusmarine) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\ratna\anaconda3\lib\site-packages (from dask>=2022->copernicusmarine) (1.0.0)
# Requirement already satisfied: locket in c:\users\ratna\anaconda3\lib\site-packages (from partd>=1.4.0->dask>=2022->copernicusmarine) (1.0.0)
# Collecting donfig>=0.8 (from zarr>=2.13.3->copernicusmarine)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr>=2.13.3->copernicusmarine)
#   Downloading numcodecs-0.16.1-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr>=2.13.3->copernicusmarine)
#   Downloading crc32c-2.7.1-cp313-cp313-win_amd64.whl.metadata (7.5 kB)
# Downloading copernicusmarine-2.1.2-py3-none-any.whl (112 kB)
# Downloading arcosparse-0.4.2-py3-none-any.whl (26 kB)
# Downloading h5netcdf-1.6.2-py3-none-any.whl (50 kB)
# Downloading pystac-1.13.0-py3-none-any.whl (206 kB)
# Downloading boto3-1.38.45-py3-none-any.whl (139 kB)
# Downloading botocore-1.38.45-py3-none-any.whl (13.7 MB)
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ---------- ----------------------------- 3.7/13.7 MB 19.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.1/13.7 MB 20.0 MB/s eta 0:00:01
#    ------------------------------------ --- 12.6/13.7 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.7/13.7 MB 19.1 MB/s eta 0:00:00
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
# Downloading zarr-3.0.8-py3-none-any.whl (205 kB)
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.1-cp313-cp313-win_amd64.whl (785 kB)
#    ---------------------------------------- 0.0/785.6 kB ? eta -:--:--
#    --------------------------------------- 785.6/785.6 kB 18.1 MB/s eta 0:00:00
# Downloading crc32c-2.7.1-cp313-cp313-win_amd64.whl (39 kB)
# Installing collected packages: numcodecs, donfig, crc32c, pystac, h5netcdf, botocore, zarr, s3transfer, arcosparse, boto3, copernicusmarine
#
#    ----------------------------------------  0/11 [numcodecs]
#    ---------- -----------------------------  3/11 [pystac]
#    -------------- -------------------------  4/11 [h5netcdf]
#   Attempting uninstall: botocore
#    -------------- -------------------------  4/11 [h5netcdf]
#     Found existing installation: botocore 1.36.3
#    -------------- -------------------------  4/11 [h5netcdf]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#     Uninstalling botocore-1.36.3:
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#       Successfully uninstalled botocore-1.36.3
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    ------------------ ---------------------  5/11 [botocore]
#    --------------------- ------------------  6/11 [zarr]
#    --------------------- ------------------  6/11 [zarr]
#    -------------------------------- -------  9/11 [boto3]
#    ------------------------------------ --- 10/11 [copernicusmarine]
#    ---------------------------------------- 11/11 [copernicusmarine]
#
# Successfully installed arcosparse-0.4.2 boto3-1.38.45 botocore-1.38.45 copernicusmarine-2.1.2 crc32c-2.7.1 donfig-0.8.1.post1 h5netcdf-1.6.2 numcodecs-0.16.1 pystac-1.13.0 s3transfer-0.13.0 zarr-3.0.8

# %% [markdown]
# **Chl-a from Global Ocean Colour (Copernicus-GlobColour), Bio-Geo-Chemical, L4 (monthly and interpolated)**
# OCEANCOLOUR_GLO_BGC_L4_MY_009_104

# %%
copernicusmarine.subset(
  dataset_id="cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M",
  variables=["CHL"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="1998-01-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
  output_filename = "cmems_oc_nwa_bgc-plankton_multi4km.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-02-11T17:33:59Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-02-11T17:34:11Z - Selected dataset version: "202411"
# INFO - 2025-02-11T17:34:11Z - Selected dataset part: "default"
# INFO - 2025-02-11T17:34:25Z - Starting download. Please wait...
#   0%|          | 0/4422 [00:00<?, ?it/s]
# INFO - 2025-02-11T17:35:20Z - Successfully downloaded to Raw Data1\cmems_oc_nwa_bgc-plankton_multi4km.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_oc_nwa_bgc-plankton_multi4km.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_oc_nwa_bgc-plankton_multi4km.nc', file_size=893.2309007633588, data_transfer_size=1280.3908396946565, variables=['CHL'], coordinates_extent=[GeographicalExtent(minimum=-77.97916412353516, maximum=-40.02082824707031, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.02083206176758, maximum=64.97916412353516, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1998-01-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %% [markdown]
# **NPP from Global Ocean Biogeochemistry Analysis and Forecast**

# %%
copernicusmarine.subset(
  dataset_id="cmems_mod_glo_bgc-bio_anfc_0.25deg_P1M-m",
  variables=["nppv"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="2022-01-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
  minimum_depth=0.4940253794193268,
  maximum_depth=100,
    output_filename = "cmems_mod_nwa_bgc-npp_forecast100.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-02-11T17:36:55Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-02-11T17:37:08Z - Selected dataset version: "202311"
# INFO - 2025-02-11T17:37:08Z - Selected dataset part: "default"
# INFO - 2025-02-11T17:37:21Z - Starting download. Please wait...
#   0%|          | 0/144 [00:00<?, ?it/s]
# INFO - 2025-02-11T17:37:56Z - Successfully downloaded to Raw Data1\cmems_mod_nwa_bgc-npp_forecast100.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_mod_nwa_bgc-npp_forecast100.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_mod_nwa_bgc-npp_forecast100.nc', file_size=61.51300763358778, data_transfer_size=288.1582900763359, variables=['nppv'], coordinates_extent=[GeographicalExtent(minimum=-78.0, maximum=-40.0, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.0, maximum=65.0, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2022-01-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time'), GeographicalExtent(minimum=0.4940253794193268, maximum=92.3260726928711, unit='m', coordinate_id='depth')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %% [markdown]
# **NPP from Global Ocean Biogeochemistry Hindcast**

# %%
import copernicusmarine
copernicusmarine.subset(
  dataset_id="cmems_mod_glo_bgc_my_0.25deg_P1M-m",
  variables=["nppv"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="1998-01-01T00:00:00",
  end_datetime="2022-12-01T00:00:00",
  minimum_depth=0.5057600140571594,
  maximum_depth=100,
    output_filename = "cmems_mod_nwa_bgc-npp_hindcast100.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-02-18T01:59:19Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-02-18T01:59:31Z - Selected dataset version: "202406"
# INFO - 2025-02-18T01:59:31Z - Selected dataset part: "default"
# INFO - 2025-02-18T01:59:48Z - Starting download. Please wait...
#   0%|          | 0/2160 [00:00<?, ?it/s]
# INFO - 2025-02-18T02:02:46Z - Successfully downloaded to Raw Data1\cmems_mod_nwa_bgc-npp_hindcast100.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_mod_nwa_bgc-npp_hindcast100.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_mod_nwa_bgc-npp_hindcast100.nc', file_size=559.2091603053435, data_transfer_size=1215.667786259542, variables=['nppv'], coordinates_extent=[GeographicalExtent(minimum=-78.0, maximum=-40.0, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.0, maximum=65.0, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1998-01-01T00:00:00+00:00', maximum='2022-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time'), GeographicalExtent(minimum=0.5057600140571594, maximum=97.04131317138672, unit='m', coordinate_id='depth')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %%
import copernicusmarine
copernicusmarine.subset(
  dataset_id="cmems_mod_glo_bgc_myint_0.25deg_P1M-m",
  variables=["nppv"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="2023-01-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
  minimum_depth=0.5057600140571594,
  maximum_depth=100,
    output_filename = "cmems_mod_nwa_bgc-npp_hindcast100_int.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-04-26T00:16:40Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-04-26T00:17:29Z - Selected dataset version: "202406"
# INFO - 2025-04-26T00:17:29Z - Selected dataset part: "default"
# INFO - 2025-04-26T00:18:57Z - Starting download. Please wait...
#   0%|          | 0/96 [00:00<?, ?it/s]
# INFO - 2025-04-26T00:20:46Z - Successfully downloaded to Raw Data1\cmems_mod_nwa_bgc-npp_hindcast100_int.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_mod_nwa_bgc-npp_hindcast100_int.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_mod_nwa_bgc-npp_hindcast100_int.nc', file_size=44.736732824427484, data_transfer_size=144.07914503816795, variables=['nppv'], coordinates_extent=[GeographicalExtent(minimum=-78.0, maximum=-40.0, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.0, maximum=65.0, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2023-01-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time'), GeographicalExtent(minimum=0.5057600140571594, maximum=97.04131317138672, unit='m', coordinate_id='depth')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %% [markdown]
# **Global Ocean Color PP MY L4**

# %%
import copernicusmarine

copernicusmarine.subset(
  dataset_id="cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M",
  variables=["PP"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="1998-01-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
    output_filename = "cmems_oc_nwa_bgc-pp_multi4km.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-07-01T04:05:18Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-07-01T04:05:30Z - Selected dataset version: "202311"
# INFO - 2025-07-01T04:05:30Z - Selected dataset part: "default"
# INFO - 2025-07-01T04:05:39Z - Starting download. Please wait...
#   0%|          | 0/1248 [00:00<?, ?it/s]
# INFO - 2025-07-01T04:21:08Z - Successfully downloaded to Raw Data1\cmems_oc_nwa_bgc-pp_multi4km.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_oc_nwa_bgc-pp_multi4km.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_oc_nwa_bgc-pp_multi4km.nc', file_size=893.2439007633589, data_transfer_size=1302.7156030534352, variables=['PP'], coordinates_extent=[GeographicalExtent(minimum=-77.97916412353516, maximum=-40.02082824707031, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.02083206176758, maximum=64.97916412353516, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1998-01-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %%
import copernicusmarine

copernicusmarine.subset(
  dataset_id="C3S-GLO-SST-L4-REP-OBS-SST",
  variables=["analysed_sst"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="1998-01-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
    output_filename = "cmems_c3s_nwa_sst_l4_rep-obs.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-07-01T04:46:20Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-07-01T04:46:33Z - Selected dataset version: "202506"
# INFO - 2025-07-01T04:46:33Z - Selected dataset part: "default"
# INFO - 2025-07-01T04:46:39Z - Starting download. Please wait...
#   0%|          | 0/10080 [00:00<?, ?it/s]
# INFO - 2025-07-01T07:03:22Z - Successfully downloaded to Raw Data1\cmems_c3s_nwa_sst_l4_rep-obs.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_c3s_nwa_sst_l4_rep-obs.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_c3s_nwa_sst_l4_rep-obs.nc', file_size=9411.713763358779, data_transfer_size=52003.56641221374, variables=['analysed_sst'], coordinates_extent=[GeographicalExtent(minimum=-77.97500610351562, maximum=-40.02500534057617, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.025001525878906, maximum=64.97500610351562, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1998-01-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %% [markdown]
# **Global Ocean Colour Plankton MY L4**
# OCEANCOLOUR_GLO_BGC_L4_MY_009_108

# %%
copernicusmarine.subset(
  dataset_id="c3s_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M",
  variables=["CHL"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="1998-01-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
    output_filename = "cmems_oc_c3s_nwa_bgc-plankton_multi4km.nc",
  output_directory = 'Raw Data1/',
)
# Out:
# INFO - 2025-02-11T17:44:24Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-02-11T17:44:32Z - Selected dataset version: "202207"
# INFO - 2025-02-11T17:44:32Z - Selected dataset part: "default"
# INFO - 2025-02-11T17:44:44Z - Starting download. Please wait...
#   0%|          | 0/1104 [00:00<?, ?it/s]
# INFO - 2025-02-11T17:45:26Z - Successfully downloaded to Raw Data1\cmems_oc_c3s_nwa_bgc-plankton_multi4km.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_oc_c3s_nwa_bgc-plankton_multi4km.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_oc_c3s_nwa_bgc-plankton_multi4km.nc', file_size=893.2309007633588, data_transfer_size=1464.8046412213741, variables=['CHL'], coordinates_extent=[GeographicalExtent(minimum=-77.97916412353516, maximum=-40.02083206176758, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.02083206176758, maximum=64.97916412353516, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1998-01-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %% [markdown]
# **SST from Global Reanalysis**

# %%
import copernicusmarine

copernicusmarine.subset(
  dataset_id="cmems_mod_glo_phy_my_0.083deg_P1M-m",
  variables=["thetao"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="1998-01-01T00:00:00",
  end_datetime="2021-06-01T00:00:00",
  minimum_depth=0.49402499198913574,
  maximum_depth=100,
    output_filename = "cmems_mod_nwa_phy-thetao_reanalysis100.nc",
  output_directory = 'Raw Data1/'
)
# Out:
# INFO - 2025-02-13T19:02:42Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-02-13T19:02:53Z - Selected dataset version: "202311"
# INFO - 2025-02-13T19:02:53Z - Selected dataset part: "default"
# INFO - 2025-02-13T19:03:15Z - Starting download. Please wait...
#   0%|          | 0/14146 [00:00<?, ?it/s]
# INFO - 2025-02-13T19:10:52Z - Successfully downloaded to Raw Data1\cmems_mod_nwa_phy-thetao_reanalysis100.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_mod_nwa_phy-thetao_reanalysis100.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_mod_nwa_phy-thetao_reanalysis100.nc', file_size=4296.127923664122, data_transfer_size=7858.316702290076, variables=['thetao'], coordinates_extent=[GeographicalExtent(minimum=-78.0, maximum=-40.0, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.0, maximum=65.0, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='1998-01-01T00:00:00+00:00', maximum='2021-06-01T00:00:00+00:00', unit='iso8601', coordinate_id='time'), GeographicalExtent(minimum=0.49402499198913574, maximum=92.3260726928711, unit='m', coordinate_id='depth')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %%
import copernicusmarine

copernicusmarine.subset(
  dataset_id="cmems_mod_glo_phy_myint_0.083deg_P1M-m",
  variables=["thetao"],
  minimum_longitude=-78,
  maximum_longitude=-40,
  minimum_latitude=32,
  maximum_latitude=65,
  start_datetime="2021-07-01T00:00:00",
  end_datetime="2024-12-01T00:00:00",
  minimum_depth=0.49402499198913574,
  maximum_depth=0.49402499198913574,
    output_filename = "cmems_mod_nwa_phy-sst_myint.nc",
  output_directory = 'Raw Data1/'
)
# Out:
# INFO - 2025-04-07T13:22:59Z - Downloading Copernicus Marine data requires a Copernicus Marine username and password, sign up for free at: https://data.marine.copernicus.eu/register
# Copernicus Marine username:
#   rsuhita
# Copernicus Marine password:
#   ········
# INFO - 2025-04-07T13:23:11Z - Selected dataset version: "202311"
# INFO - 2025-04-07T13:23:11Z - Selected dataset part: "default"
# INFO - 2025-04-07T13:23:30Z - Starting download. Please wait...
#   0%|          | 0/128 [00:00<?, ?it/s]
# INFO - 2025-04-07T13:23:57Z - Successfully downloaded to Raw Data1\cmems_mod_nwa_phy-sst_myint.nc
# ResponseSubset(file_path=WindowsPath('Raw Data1/cmems_mod_nwa_phy-sst_myint.nc'), output_directory=WindowsPath('Raw Data1'), filename='cmems_mod_nwa_phy-sst_myint.nc', file_size=58.16807633587786, data_transfer_size=480.2638167938931, variables=['thetao'], coordinates_extent=[GeographicalExtent(minimum=-78.0, maximum=-40.0, unit='degrees_east', coordinate_id='longitude'), GeographicalExtent(minimum=32.0, maximum=65.0, unit='degrees_north', coordinate_id='latitude'), TimeExtent(minimum='2021-07-01T00:00:00+00:00', maximum='2024-12-01T00:00:00+00:00', unit='iso8601', coordinate_id='time'), GeographicalExtent(minimum=0.49402499198913574, maximum=0.49402499198913574, unit='m', coordinate_id='depth')], status='000', message='The request was successful.', file_status='DOWNLOADED')

# %% [markdown]
# **PAR from NASA Ocean Color**

# %%
# !pip install earthaccess
# Out:
# Collecting earthaccess
#   Downloading earthaccess-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: fsspec>=2022.11 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from earthaccess) (2024.6.1)
# Collecting importlib-resources>=6.3.2 (from earthaccess)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting multimethod>=1.8 (from earthaccess)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting pqdm>=0.1 (from earthaccess)
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting python-cmr>=0.10.0 (from earthaccess)
#   Downloading python_cmr-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.26 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from earthaccess) (2.32.3)
# Requirement already satisfied: s3fs>=2022.11 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from earthaccess) (2024.6.1)
# Collecting tinynetrc>=1.3.1 (from earthaccess)
#   Downloading tinynetrc-1.3.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from earthaccess) (4.12.2)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess)
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tqdm in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from pqdm>=0.1->earthaccess) (4.66.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from python-cmr>=0.10.0->earthaccess) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from requests>=2.26->earthaccess) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from requests>=2.26->earthaccess) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from requests>=2.26->earthaccess) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from requests>=2.26->earthaccess) (2024.8.30)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from s3fs>=2022.11->earthaccess) (2.12.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from s3fs>=2022.11->earthaccess) (3.10.5)
# Collecting botocore<1.34.70,>=1.34.41 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess)
#   Downloading botocore-1.34.69-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (0.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2022.11->earthaccess) (1.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->python-cmr>=0.10.0->earthaccess) (1.16.0)
# Requirement already satisfied: colorama in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from tqdm->pqdm>=0.1->earthaccess) (0.4.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\nsuhita\appdata\local\anaconda3\lib\site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs>=2022.11->earthaccess) (1.0.1)
# Downloading earthaccess-0.14.0-py3-none-any.whl (64 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Downloading python_cmr-0.13.0-py3-none-any.whl (14 kB)
# Downloading tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Downloading botocore-1.34.69-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/12.0 MB 11.2 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.0 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.8/12.0 MB 12.0 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/12.0 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  11.8/12.0 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 11.4 MB/s eta 0:00:00
# Installing collected packages: tinynetrc, bounded-pool-executor, multimethod, importlib-resources, python-cmr, pqdm, botocore, earthaccess
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.96
#     Uninstalling botocore-1.35.96:
#       Successfully uninstalled botocore-1.35.96
# Successfully installed botocore-1.34.69 bounded-pool-executor-0.0.3 earthaccess-0.14.0 importlib-resources-6.5.2 multimethod-2.0 pqdm-0.2.0 python-cmr-0.13.0 tinynetrc-1.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.35.96 requires botocore<1.36.0,>=1.35.96, but you have botocore 1.34.69 which is incompatible.

# %% [raw]
# import earthaccess
# auth = earthaccess.login(persist=True)

# %% [raw]
# results =earthaccess.search_datasets(
#     short_name='MODISA_L3m_PAR',
#     bounding_box=(-78, 32, -40, 65),
#     processing_level_id=3,
#     temporal=('1998-01-01', '2010-12-11')
# )
#
# results
# #downloaded_files = earthaccess.download(
# #    results,
# #    local_path='PAR/',
# #)

# %% [raw]
# results1 =earthaccess.search_datasets(
#     short_name='SeaWIFS_L3m_PAR',
#     bounding_box=(-78, 32, -40, 65),
#     processing_level_id=3,
#     temporal=('1998-01-01', '2010-12-11')
# )
#
# results1

# %% [markdown]
# # EXPLORE THE DATASET

# %%
# Import libraries
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches
import cartopy.crs as ccrs
import cartopy.feature as creature
import glob
import datetime
import pandas as pd
import geopandas as gpd
import seaborn as sns

# To avoid warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
data_pp = 'Raw Data1/cmems_oc_nwa_bgc-pp_multi4km.nc'
pp = xr.open_dataset(data_pp)

pp
# Out:
# <xarray.Dataset> Size: 936MB
# Dimensions:    (time: 324, latitude: 792, longitude: 912)
# Coordinates:
#   * latitude   (latitude) float32 3kB 32.02 32.06 32.1 ... 64.9 64.94 64.98
#   * longitude  (longitude) float32 4kB -77.98 -77.94 -77.9 ... -40.06 -40.02
#   * time       (time) datetime64[ns] 3kB 1998-01-01 1998-02-01 ... 2024-12-01
# Data variables:
#     PP         (time, latitude, longitude) float32 936MB ...
# Attributes:
#     history:                   Created using software developed at ACRI-ST
#     Conventions:               CF-1.8, ACDD-1.3
#     title:                     cmems_obs-oc_glo_bgc-pp_my_l4-multi-4km_P1M
#     source:                    surface observation
#     institution:               ACRI
#     contact:                   servicedesk.cmems@acri-st.fr
#     comment:                   average
#     references:                http://www.globcolour.info GlobColour has been...
#     copernicusmarine_version:  2.1.2

# %%
# Load the file

data = 'Raw Data1/cmems_oc_nwa_bgc-plankton_multi4km.nc'
ds_chl = xr.open_dataset(data)
ds_chl

#ds_chl.to_dataframe().reset_index()
# Out:
# <xarray.Dataset> Size: 936MB
# Dimensions:    (time: 324, latitude: 792, longitude: 912)
# Coordinates:
#   * latitude   (latitude) float32 3kB 32.02 32.06 32.1 ... 64.9 64.94 64.98
#   * longitude  (longitude) float32 4kB -77.98 -77.94 -77.9 ... -40.06 -40.02
#   * time       (time) datetime64[ns] 3kB 1998-01-01 1998-02-01 ... 2024-12-01
# Data variables:
#     CHL        (time, latitude, longitude) float32 936MB ...
# Attributes:
#     Conventions:               CF-1.8, ACDD-1.3
#     institution:               ACRI
#     references:                http://www.globcolour.info GlobColour has been...
#     history:                   Created using software developed at ACRI-ST
#     contact:                   servicedesk.cmems@acri-st.fr
#     source:                    surface observation
#     title:                     cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M
#     comment:                   average
#     copernicusmarine_version:  2.0.0

# %% [markdown]
# **Calculate and plot chl-a value by month**
#
# using resample function

# %%
# Subset dataset by EPUs' shapefile
# Load the shapefile
shapefile_path = r'\Users\ratna\OneDrive\Documents\NPP\EPUs\EPUs.shp'
gdf = gpd.read_file(shapefile_path)

# Reproject the GeoDataFrame to GCS (EPSG:4326)
gdf = gdf.to_crs(epsg=4326)

ds_chl_subset = ds_chl.sel(
    latitude=slice(gdf.bounds.miny.min(), gdf.bounds.maxy.max()), 
    longitude=slice(gdf.bounds.minx.min(), gdf.bounds.maxx.max())
)

# Group data by month and calculate the mean
##ds_mean_bymonth = ds_chl_subset.resample(time="1M").mean()
#ds_mean_bymonth

# Save to csv
#ds_monthly_mean.to_dataframe().to_csv('monthly_mean_data.csv')

#ds_mean_bymonth['month'] = ds_mean_bymonth['time'].dt.month
#ds_mean_bymonth = ds_mean_bymonth.assign_coords(month=ds_mean_bymonth['time'].dt.month)

# Select 1 month to map
#month_to_plot = 1  # 1 = January
#ds_selected_month = ds_mean_bymonth.sel(month=month_to_plot)

# Make a plot using Cartopy and Matplotlib
#fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Plot data
#ds_selected_month['CHL'].plot(ax=ax, transform=ccrs.PlateCarree(), vmin = 0, vmax=1, cmap='viridis')

# Add shapefile to map
#gdf.boundary.plot(ax=ax, color='black', linewidth=1)

# Add map elements
#ax.set_title(f'Mean Value for Month {month_to_plot}')
#ax.coastlines(resolution='50m', linewidth=1)
#ax.gridlines(draw_labels=True)

# Display the plot
#plt.show()

# %% [markdown]
# **Calculate and plot chl-a value by month**
#
# using groupby function

# %%
# Group data by month and calculate the mean
ds_mean_bymonth1 = ds_chl_subset.groupby('time.month').mean('time')
ds_mean_bymonth1

# Select 1 month to map
month_to_plot = 1  # 1 = January
ds_selected_month = ds_mean_bymonth1.sel(month=month_to_plot)

# Make a plot using Cartopy and Matplotlib
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': ccrs.PlateCarree()})

# Plot data
ds_selected_month['CHL'].plot(ax=ax, transform=ccrs.PlateCarree(), vmin = 0, vmax=1, cmap='viridis')

# Add shapefile to map
gdf.boundary.plot(ax=ax, color='black', linewidth=1)

# Add map elements
ax.set_title(f'Mean Value for Month {month_to_plot}')
ax.coastlines(resolution='50m', linewidth=1)
ax.gridlines(draw_labels=True)

# Display the plot
plt.show()

#fig.savefig('Chl_January.png', dpi=300, transparent=True)

# %% [markdown]
# **Plot chl-a and SST**

# %%
# Load dataset

data1 = 'Raw Data1\cmems_mod_nwa_phy-thetao_reanalysis.nc'
open_data1 = xr.open_dataset(data1)

# %%
ds_temp = open_data1.squeeze(dim='depth')
ds_temp = ds_temp.drop_vars('depth')
ds_temp
# Out:
# <xarray.Dataset> Size: 409MB
# Dimensions:    (latitude: 397, longitude: 457, time: 282)
# Coordinates:
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * time       (time) datetime64[ns] 2kB 1998-01-01 1998-02-01 ... 2021-06-01
# Data variables:
#     thetao     (time, latitude, longitude) float64 409MB ...
# Attributes:
#     Conventions:               CF-1.6
#     institution:               Mercator Ocean
#     references:                http://marine.copernicus.eu
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     source:                    MERCATOR GLORYS12V1
#     title:                     Monthly mean fields for product GLOBAL_REANALY...
#     producer:                  CMEMS - Global Monitoring and Forecasting Centre
#     credit:                    E.U. Copernicus Marine Service Information (CM...
#     copernicusmarine_version:  2.0.0

# %%
# Load dataset

data2 = 'Raw Data1\cmems_mod_nwa_phy-sst_myint.nc'
open_data2 = xr.open_dataset(data2)

open_data2
# Out:
# <xarray.Dataset> Size: 61MB
# Dimensions:    (depth: 1, latitude: 397, longitude: 457, time: 42)
# Coordinates:
#   * depth      (depth) float32 4B 0.494
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * time       (time) datetime64[ns] 336B 2021-07-01 2021-08-01 ... 2024-12-01
# Data variables:
#     thetao     (time, depth, latitude, longitude) float64 61MB ...
# Attributes:
#     title:                     Monthly mean fields for product GLOBAL_REANALY...
#     producer:                  CMEMS - Global Monitoring and Forecasting Centre
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     credit:                    E.U. Copernicus Marine Service Information (CM...
#     references:                http://marine.copernicus.eu
#     Conventions:               CF-1.6
#     source:                    MERCATOR GLORYS12V1
#     institution:               Mercator Ocean
#     copernicusmarine_version:  2.0.0

# %%
ds_temp1 = open_data2.squeeze(dim='depth')
ds_temp1 = ds_temp1.drop_vars('depth')
ds_temp1
# Out:
# <xarray.Dataset> Size: 61MB
# Dimensions:    (latitude: 397, longitude: 457, time: 42)
# Coordinates:
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * time       (time) datetime64[ns] 336B 2021-07-01 2021-08-01 ... 2024-12-01
# Data variables:
#     thetao     (time, latitude, longitude) float64 61MB ...
# Attributes:
#     title:                     Monthly mean fields for product GLOBAL_REANALY...
#     producer:                  CMEMS - Global Monitoring and Forecasting Centre
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     credit:                    E.U. Copernicus Marine Service Information (CM...
#     references:                http://marine.copernicus.eu
#     Conventions:               CF-1.6
#     source:                    MERCATOR GLORYS12V1
#     institution:               Mercator Ocean
#     copernicusmarine_version:  2.0.0

# %%
# For some reason, the precision on the longitude is different from the two dataset.
# This ends up duplicating this axis if we don't round.
ds_temp['longitude'] = ds_temp.longitude.round(4)
ds_temp['latitude'] = ds_temp.latitude.round(4)
ds_temp1['longitude'] = ds_temp1.longitude.round(4)
ds_temp1['latitude'] = ds_temp1.latitude.round(4)

# Merge the datasets:
ds_temp_concat = xr.concat([ds_temp, ds_temp1], dim='time')
ds_temp_concat
# Out:
# <xarray.Dataset> Size: 470MB
# Dimensions:    (time: 324, latitude: 397, longitude: 457)
# Coordinates:
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * time       (time) datetime64[ns] 3kB 1998-01-01 1998-02-01 ... 2024-12-01
# Data variables:
#     thetao     (time, latitude, longitude) float64 470MB 23.86 24.21 ... -1.55
# Attributes:
#     Conventions:               CF-1.6
#     institution:               Mercator Ocean
#     references:                http://marine.copernicus.eu
#     contact:                   servicedesk.cmems@mercator-ocean.eu
#     source:                    MERCATOR GLORYS12V1
#     title:                     Monthly mean fields for product GLOBAL_REANALY...
#     producer:                  CMEMS - Global Monitoring and Forecasting Centre
#     credit:                    E.U. Copernicus Marine Service Information (CM...
#     copernicusmarine_version:  2.0.0

# %%
interp_chl = ds_chl.interp(latitude=ds_temp_concat["latitude"], longitude = ds_temp_concat["longitude"])

interp_chl
# Out:
# <xarray.Dataset> Size: 235MB
# Dimensions:    (time: 324, latitude: 397, longitude: 457)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 1998-01-01 1998-02-01 ... 2024-12-01
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
# Data variables:
#     CHL        (time, latitude, longitude) float32 235MB nan nan nan ... nan nan
# Attributes:
#     Conventions:               CF-1.8, ACDD-1.3
#     institution:               ACRI
#     references:                http://www.globcolour.info GlobColour has been...
#     history:                   Created using software developed at ACRI-ST
#     contact:                   servicedesk.cmems@acri-st.fr
#     source:                    surface observation
#     title:                     cmems_obs-oc_glo_bgc-plankton_my_l4-multi-4km_P1M
#     comment:                   average
#     copernicusmarine_version:  2.0.0

# %% [raw]
# interp_chl.to_dataframe().to_csv('interpolated chl data.csv')

# %%
lat_sst = ds_temp['latitude'].values
lon_sst = ds_temp['longitude'].values

#lat_chl_flat = lat_chl.flatten()
#lon_chl_flat = lon_chl.flatten()

#lat_sst_flat = lat_sst.flatten()
#lon_sst_flat = lon_sst.flatten()

# Plot chl-a
#plt.figure(figsize=(14, 7))

# Plot grid for chl-a
#plt.subplot(1, 2, 1)
#plt.scatter(lon_chl_flat,lat_chl_flat, cmap='viridis', marker='o')
#plt.colorbar(label='Klorofil-a (mg/m³)')  # Skala warna untuk klorofil-a
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.title('Distribusi Klorofil-a')

# Plot grid for sst
#plt.subplot(1, 2, 2)
#plt.scatter(lon_sst_flat, lat_sst_flat, cmap='coolwarm', marker='o')
#plt.colorbar(label='Suhu (°C)')  # Skala warna untuk suhu
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.title('Distribusi Suhu')

#plt.tight_layout()
plt.show()

# %% [markdown]
# **Reduced resolution using averaged data by season**

# %%
# Compute seasonal average

#seasonal_sst = ds_temp.groupby("time.season").mean('time')
#seasonal_sst

# %% [markdown]
# **Reduced resolution using averaged data by month**

# %%
# Compute monthly average

#monthly_sst = ds_temp.groupby("time.month").mean('time')
#monthly_sst

# %% [raw]
# # importing the "tarfile" module
# #import tarfile
#
# # open file
# #file = tarfile.open('requested_files_1.tar')
#
# # extracting file
# #file.extractall('./PAR')
#
# #file.close()

# %%
import glob
import os

# Specify the path folder where the NetCDF datasets are stored
folder_path = r'C:\Users\ratna\OneDrive\Documents\NPP\PAR\MODIS'

#files_in_folder = os.listdir(folder_path)
#print(files_in_folder)                #to display a list of all datasets
# print(os.path.exists(folder_path))   #to verify that we input the right path folder
# print(os.getcwd())                   #to check current working directory

# Find all files with .nc extension in a specific folder
file_path = glob.glob(os.path.join(folder_path, '*.nc'))

# Sort the files to make sure they are in the correct order
file_path.sort()

# Create a date range from January 2008 to December 2024
# Assuming the files are ordered from January 2008 to December 2024
time_index = pd.date_range('2008-01-01', '2024-12-31', freq='MS')

# Convert the time_index to numpy datetime64 type
time_index = time_index.to_numpy()

# Read all file NetCDF menggunakan xarray dan simpan dalam list
par_modis = xr.open_mfdataset(file_path, combine = 'nested', concat_dim = 'time', data_vars='minimal', coords='minimal', compat='override')  # define "engine=netcdf3" if needed

# Create a new time dimension using the sorted file order and convert it to datetime64
par_modis.coords['time'] = ('time', time_index)

#par_modis.to_netcdf(r'C:\Users\ratna\OneDrive\Documents\NPP\Temporary output\par_modis_combined.nc')

# %%
par_modis_combined = r'\Users\ratna\OneDrive\Documents\NPP\Temporary output\par_modis_combined.nc'
open_par_modis = xr.open_dataset(par_modis_combined)
open_par_modis
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:  (lat: 792, lon: 912, rgb: 3, eightbitcolor: 256, time: 204)
# Coordinates:
#   * lat      (lat) float32 3kB 64.98 64.94 64.9 64.85 ... 32.15 32.1 32.06 32.02
#   * lon      (lon) float32 4kB -77.98 -77.94 -77.9 ... -40.1 -40.06 -40.02
#   * time     (time) datetime64[ns] 2kB 2008-01-01 2008-02-01 ... 2024-12-01
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     par      (lat, lon) float32 3MB ...
#     palette  (rgb, eightbitcolor) uint8 768B ...
# Attributes: (12/61)
#     product_name:                     AQUA_MODIS.20080101_20080131.L3m.MO.PAR...
#     instrument:                       MODIS
#     title:                            MODISA Level-3 Equidistant Cylindrical ...
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Aqua
#     source:                           satellite observations from MODIS-Aqua
#     ...                               ...
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
#     proj4_string:                     +proj=eqc +lat_ts=0 +lat_0=0 +x_0=0 +y_...
#     data_bins:                        435931
#     data_minimum:                     0.013999938
#     data_maximum:                     27.056

# %%
# Resample par_modis_combined dataset using coordinates from SST datasets

interp_par_modis = open_par_modis.interp(lat=ds_temp_concat["latitude"], lon = ds_temp_concat["longitude"])

interp_par_modis
# Out:
# <xarray.Dataset> Size: 735kB
# Dimensions:    (latitude: 397, longitude: 457, rgb: 3, eightbitcolor: 256,
#                 time: 204)
# Coordinates:
#   * time       (time) datetime64[ns] 2kB 2008-01-01 2008-02-01 ... 2024-12-01
#     lat        (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#     lon        (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     par        (latitude, longitude) float32 726kB nan nan nan ... nan nan nan
#     palette    (rgb, eightbitcolor) uint8 768B 147 0 108 144 0 111 ... 0 0 0 0 0
# Attributes: (12/61)
#     product_name:                     AQUA_MODIS.20080101_20080131.L3m.MO.PAR...
#     instrument:                       MODIS
#     title:                            MODISA Level-3 Equidistant Cylindrical ...
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Aqua
#     source:                           satellite observations from MODIS-Aqua
#     ...                               ...
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
#     proj4_string:                     +proj=eqc +lat_ts=0 +lat_0=0 +x_0=0 +y_...
#     data_bins:                        435931
#     data_minimum:                     0.013999938
#     data_maximum:                     27.056

# %%
import glob
import os

# Specify the path folder where the NetCDF datasets are stored
folder_path2 = r'C:\Users\ratna\OneDrive\Documents\NPP\PAR\SEAWIFS'

# Find all files with .nc extension in a specific folder
file_path2 = glob.glob(os.path.join(folder_path2, '*.nc'))

# Sort the files to make sure they are in the correct order
file_path2.sort()

# Create a date range from January 1998 to December 2007
# Assuming the files are ordered from January 1998 to December 2007
time_index2 = pd.date_range('1998-01-01', '2007-12-31', freq='MS')

# Convert the time_index to numpy datetime64 type
time_index2 = time_index2.to_numpy()

# Read all file NetCDF menggunakan xarray dan simpan dalam list
par_seawifs = xr.open_mfdataset(file_path2, combine = 'nested', concat_dim = 'time', data_vars='minimal', coords='minimal', compat='override')

# Create a new time dimension using the sorted file order and convert it to datetime64
par_seawifs.coords['time'] = ('time', time_index2)

#par_seawifs.to_netcdf(r'C:\Users\ratna\OneDrive\Documents\NPP\Temporary output\par_seawifs_combined.nc')

# %%
par_seawifs = r'\Users\ratna\OneDrive\Documents\NPP\Temporary output\par_seawifs_combined.nc'
open_par_sea = xr.open_dataset(par_seawifs)
open_par_sea
# Out:
# <xarray.Dataset> Size: 727kB
# Dimensions:  (lat: 396, lon: 456, rgb: 3, eightbitcolor: 256, time: 120)
# Coordinates:
#   * lat      (lat) float32 2kB 64.96 64.88 64.79 64.71 ... 32.21 32.12 32.04
#   * lon      (lon) float32 2kB -77.96 -77.88 -77.79 ... -40.21 -40.12 -40.04
#   * time     (time) datetime64[ns] 960B 1998-01-01 1998-02-01 ... 2007-12-01
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     par      (lat, lon) float32 722kB ...
#     palette  (rgb, eightbitcolor) uint8 768B ...
# Attributes: (12/61)
#     product_name:                     SEASTAR_SEAWIFS_GAC.19980101_19980131.L...
#     instrument:                       SeaWiFS
#     title:                            SeaWiFS Level-3 Equidistant Cylindrical...
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Orbview-2
#     source:                           satellite observations from SeaWiFS-Orb...
#     ...                               ...
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
#     proj4_string:                     +proj=eqc +lat_ts=0 +lat_0=0 +x_0=0 +y_...
#     data_bins:                        111417
#     data_minimum:                     0.013999938
#     data_maximum:                     33.746998

# %%
# Resample par_modis_combined dataset using coordinates from SST datasets

interp_par_seawifs = open_par_sea.interp(lat=ds_temp_concat["latitude"], lon = ds_temp_concat["longitude"])

interp_par_seawifs
# Out:
# <xarray.Dataset> Size: 734kB
# Dimensions:    (latitude: 397, longitude: 457, rgb: 3, eightbitcolor: 256,
#                 time: 120)
# Coordinates:
#   * time       (time) datetime64[ns] 960B 1998-01-01 1998-02-01 ... 2007-12-01
#     lat        (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#     lon        (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     par        (latitude, longitude) float32 726kB nan nan nan ... nan nan nan
#     palette    (rgb, eightbitcolor) uint8 768B 147 0 108 144 0 111 ... 0 0 0 0 0
# Attributes: (12/61)
#     product_name:                     SEASTAR_SEAWIFS_GAC.19980101_19980131.L...
#     instrument:                       SeaWiFS
#     title:                            SeaWiFS Level-3 Equidistant Cylindrical...
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Orbview-2
#     source:                           satellite observations from SeaWiFS-Orb...
#     ...                               ...
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
#     proj4_string:                     +proj=eqc +lat_ts=0 +lat_0=0 +x_0=0 +y_...
#     data_bins:                        111417
#     data_minimum:                     0.013999938
#     data_maximum:                     33.746998

# %% [markdown]
# **Combine both par datasets**

# %%
# Specify spesific time range from par_modis_combined (using index of time)
#start_time_index = 96
#end_time_index = 263

# Select and filter time range from par_modis_combined
#interp_mod_filtered = interp_par_modis.sel(time=slice(interp_par_modis['time'][start_time_index], interp_par_modis['time'][end_time_index]))

# Display filtered data from par_modis_combined
#print(interp_mod_filtered)

# Combine datasets using the same dimension, i.e. time
par_combined = xr.concat([interp_par_seawifs, interp_par_modis], dim='time')

par_combined
# Display combined par datasets
#print(par_combined)
# Out:
# <xarray.Dataset> Size: 235MB
# Dimensions:    (time: 324, latitude: 397, longitude: 457, rgb: 3,
#                 eightbitcolor: 256)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 1998-01-01 1998-02-01 ... 2024-12-01
#     lat        (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#     lon        (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
# Dimensions without coordinates: rgb, eightbitcolor
# Data variables:
#     par        (time, latitude, longitude) float32 235MB nan nan nan ... nan nan
#     palette    (time, rgb, eightbitcolor) uint8 249kB 147 0 108 144 ... 0 0 0 0
# Attributes: (12/61)
#     product_name:                     SEASTAR_SEAWIFS_GAC.19980101_19980131.L...
#     instrument:                       SeaWiFS
#     title:                            SeaWiFS Level-3 Equidistant Cylindrical...
#     project:                          Ocean Biology Processing Group (NASA/GS...
#     platform:                         Orbview-2
#     source:                           satellite observations from SeaWiFS-Orb...
#     ...                               ...
#     processing_level:                 L3 Mapped
#     cdm_data_type:                    grid
#     proj4_string:                     +proj=eqc +lat_ts=0 +lat_0=0 +x_0=0 +y_...
#     data_bins:                        111417
#     data_minimum:                     0.013999938
#     data_maximum:                     33.746998

# %% [markdown]
# **Combine all datasets into single netcdf file**

# %%
par_no_dims = par_combined.drop_vars(['lon', 'lat'])
#sst_no_depth = ds_temp.drop_vars(['depth'])

# Choose desired variables
var1 = interp_chl['CHL']  
var2 = ds_temp_concat['thetao']  
var3 = par_no_dims['par'] 

# Combine more variables
dataset_combined = xr.Dataset({
    'CHL': var1,
    'SST': var2,
    'PAR': var3,
})

dataset_combined
# Save to new netcdf file
#dataset_combined.to_netcdf(r'C:\Users\ratna\OneDrive\Documents\NPP\Temporary output\combined file with all vars1.nc')
# Out:
# <xarray.Dataset> Size: 941MB
# Dimensions:    (time: 324, latitude: 397, longitude: 457)
# Coordinates:
#   * time       (time) datetime64[ns] 3kB 1998-01-01 1998-02-01 ... 2024-12-01
#   * latitude   (latitude) float32 2kB 32.0 32.08 32.17 ... 64.83 64.92 65.0
#   * longitude  (longitude) float32 2kB -78.0 -77.92 -77.83 ... -40.08 -40.0
# Data variables:
#     CHL        (time, latitude, longitude) float32 235MB nan nan nan ... nan nan
#     SST        (time, latitude, longitude) float64 470MB 23.86 24.21 ... -1.55
#     PAR        (time, latitude, longitude) float32 235MB nan nan nan ... nan nan

# %%
# Convert to DataFrame
df = dataset_combined.to_dataframe().reset_index()

# Display DataFrame
print(df)
# Out:
#                time  latitude  longitude  CHL        SST  PAR
# 0        1998-01-01      32.0 -78.000000  NaN  23.863857  NaN
# 1        1998-01-01      32.0 -77.916702  NaN  24.208838  NaN
# 2        1998-01-01      32.0 -77.833298  NaN  24.564806  NaN
# 3        1998-01-01      32.0 -77.750000  NaN  24.857051  NaN
# 4        1998-01-01      32.0 -77.666702  NaN  25.023316  NaN
# ...             ...       ...        ...  ...        ...  ...
# 58782991 2024-12-01      65.0 -40.333302  NaN        NaN  NaN
# 58782992 2024-12-01      65.0 -40.250000  NaN        NaN  NaN
# 58782993 2024-12-01      65.0 -40.166698  NaN  -1.628864  NaN
# 58782994 2024-12-01      65.0 -40.083302  NaN  -1.598834  NaN
# 58782995 2024-12-01      65.0 -40.000000  NaN  -1.550493  NaN
#
# [58782996 rows x 6 columns]

# %%
sal_lab.mean(dim=('tile','i','j')).plot(ax = axes[0])
axes[0].set_title('Surface salinity - Labrador Sea')
axes[0].grid(which = 'major', linestyle = 'dotted', color = '0.6')
axes[0].set_xlim('1992','2016')

plt.plot(x, y, label = "line 1", linestyle="-")
plt.plot(y, x, label = "line 2", linestyle="--")
plt.plot(x, np.sin(x), label = "curve 1", linestyle="-.")
plt.plot(x, np.cos(x), label = "curve 2", linestyle=":")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sal_lab.mean(dim=('tile','i','j')).plot(ax = axes[0])
#       2 axes[0].set_title('Surface salinity - Labrador Sea')
#       3 axes[0].grid(which = 'major', linestyle = 'dotted', color = '0.6')
#
# NameError: name 'sal_lab' is not defined

# %%
# Calculate annual mean by averaging monthly data into annual mean
npp_fore_annual = npp.resample(time='Y').mean(skipna=True)  # Resample berdasarkan tahun (Y = year)
npp_hind_annual = npp1.resample(time='Y').mean(skipna=True)  # Resample berdasarkan tahun

# Plotting both datasets
plt.figure(figsize=(10, 6))

# Plot variable from both dataset
npp_fore_annual.plot(label='fNPP', color='blue')
npp_hind_annual.plot(label='hNPP', color='red')

# Add label and title
plt.xlabel('')
plt.ylabel('')
plt.title('')

# Add legend
plt.legend()

# Customize grid
plt.grid(True/false)

# Adjust the display
plt.tight_layout()

# Show the plot
plt.show()

# %%
tas_NW_yr_hist = ds_hist_sel.isel(lat = (ds_hist_sel.lat>=bottom) & (ds_hist_sel.lat<=top),
                   lon = (ds_hist_sel.lon>=left) & (ds_hist_sel.lon<=right),
                   ).mean(['lat','lon']).drop(['bnds', 'height', 'time_bnds'])
tas_NW_yr_ssp585 = ds_ssp585_sel.isel(lat = (ds_ssp585_sel.lat>=bottom) & (ds_ssp585_sel.lat<=top),
                   lon = (ds_ssp585_sel.lon>=left) & (ds_ssp585_sel.lon<=right),
                   ).mean(['lat','lon']).drop(['bnds', 'height', 'time_bnds'])

# %%
plt.figure(figsize=[8,5],)
(tas_NW_yr_hist.groupby('time.year').mean().tas-273.15).plot(
    label='historical', color='b', linewidth=2)
(tas_NW_yr_ssp585.groupby('time.year').mean().tas-273.15).plot(
    label='ssp585', color='r', linewidth=2)
plt.grid()
plt.xlim([1980,2100])
plt.legend(fontsize=13)
plt.xticks(fontsize=12)
plt.yticks(fontsize=13)
plt.ylabel('Average Annual Temperature (°C)', fontsize=13, fontweight='bold')
plt.xlabel('Year', fontsize=13, fontweight='bold')
plt.title(f'Average Annual air temperature in the Cascades: {model} ssp585',
          fontsize=15)

plt.tight_layout()
